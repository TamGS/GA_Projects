# %% [markdown]
# ### Challenge 1: Largest Palindrome
# A palindromic number reads the same both ways. For example, 1234321 is a palindrome. The largest palindrome made from the product of two two-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two three-digit numbers. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
largest_palindrome = 0

for i in range(100,1000):
    for j in range(100,1000):
        product = i * j
        str_product = str(product)
        reverse_str_product = str_product[::-1]

        if str_product == reverse_str_product:
            if product > largest_palindrome:
                largest_palindrome = product
                largest_i = i
                largest_j = j

print(str(largest_i) + '*' + str(largest_j) + "=" + str(largest_palindrome), end='= largest palindrome made from the product of two three-digit numbers')
# Out:
# 913*993=906609= largest palindrome made from the product of two three-digit numbers

# %% [raw]
# # Challenge 1: Largest Palindrome solution
#
# largest_palindrome = 0             #initialize result data
#
# for i in range(100,1000):          #create a for-loop from 100-999
#     for j in range(100,1000):      #create a for-loop from 100-999
#         product = i * j            #generate product of i and j
#         str_product = str(product)                #change int object product to string product
#         reverse_str_product = str_product[::-1]   #reverse the string of str_product
#
#         if str_product == reverse_str_product:    #if string of str_product equal with reverse string of str_product
#             if product > largest_palindrome:      ## and if the product value larger than the last largest_palindrome
#                 largest_palindrome = product      ### then store the product value to largest_palindrome
#                 largest_i = i                     ### and store the i value to largest_i
#                 largest_j = j                     ### and store the j value to largest_j
#
#
# #print out the largest i, largest j and largest_palindrome
# print(str(largest_i) + '*' + str(largest_j) + "=" + str(largest_palindrome), end='= largest palindrome made from the product of two three-digit numbers')

# %% [markdown]
# ### Challenge 2: Summation of Primes
# The sum of the primes below 10 is 2 + 3 + 5 + 7 = 17. Find the sum of all the primes below 2,000. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
sum_prime=0

for i in range(2,2000):
    num_natural=0
    for j in range(2,i+1):
        if (i%j)==0:
            num_natural=num_natural+1
        
        if  num_natural>1:
            break
    
    if  num_natural==1:
        sum_prime= sum_prime + i
        #print(i, end=',')


print(sum_prime, end='= Sum of prime below 2000')
# Out:
# 277050= Sum of prime below 2000

# %% [raw]
# # Challenge 2: Summation of Primes solution
# # Natural number = 1,2,3,4,5....
# # Prime number is only can devisible by exactly 2 natural numbers, itself and 1. Eg. 5, 7, 17
# # the coding below skip the natural number 1
#
# sum_prime=0                               #initialize result data
#
# for i in range(2,2000):                   #create a for-loop from 2 to 1999
#     num_natural=0                         #initialize counter of natural number
#     for j in range(2,i+1):                #create a for-loop from 2 to i+1, Eg. If i=10, 2 to 10
#         if (i%j)==0:                      #Eg. if i =10, check reminder of 10/2, 10/3, 10/4, 10/5....10/10
#             num_natural=num_natural+1     #if reminder = 0 then increment num_natural by 1
#
#         if  num_natural>1:                #if num_natural > 1 that means it can devisible by more than 2 natural numbers
#             break                         ## then jump out for the loop and inspect the next number
#
#     if  num_natural==1:                   #once for-loop completed, check if number_natural=1, if yes that means it is a
#         sum_prime= sum_prime + i          ##prime number, add it into sum_prime to get the sum of prime
#         #print(i, end=',')
#
#
# #print out the result
# print(sum_prime, end='= Sum of prime below 2000')

# %% [markdown]
# ### Challenge 3: Multiples of 3 and 5
# If we list all of the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6, and 9. The sum of these multiples is 23. Find the sum of all the multiples of 3 and 5 below 1,000. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
sum_num1 = 0
sum_num2 = 0
num1 = 3
num2 = 5

for i in range(1,1000):
    mul_of_num1 = num1 * i
    print(mul_of_num1, end=',')
    if mul_of_num1 < 1000:
        sum_num1= mul_of_num1 + sum_num1
    else:
        break
        
for i in range(1,1000):   
    mul_of_num2 = num2 * i
    print(mul_of_num2, end=': ')
    if mul_of_num2 < 1000:
        sum_num2= mul_of_num2 + sum_num2
    else:
        break
    
print(sum_num1 + sum_num2, end = '= Sum of all the multiples of 3 and 5 below 1,000')
# Out:
# 3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147,150,153,156,159,162,165,168,171,174,177,180,183,186,189,192,195,198,201,204,207,210,213,216,219,222,225,228,231,234,237,240,243,246,249,252,255,258,261,264,267,270,273,276,279,282,285,288,291,294,297,300,303,306,309,312,315,318,321,324,327,330,333,336,339,342,345,348,351,354,357,360,363,366,369,372,375,378,381,384,387,390,393,396,399,402,405,408,411,414,417,420,423,426,429,432,435,438,441,444,447,450,453,456,459,462,465,468,471,474,477,480,483,486,489,492,495,498,501,504,507,510,513,516,519,522,525,528,531,534,537,540,543,546,549,552,555,558,561,564,567,570,573,576,579,582,585,588,591,594,597,600,603,606,609,612,615,618,621,624,627,630,633,636,639,642,645,648,651,654,657,660,663,666,669,672,675,678,681,684,687,690,693,696,699,702,705,708,711,714,717,720,723,726,729,732,735,738,741,744,747,750,753,756,759,762,765,768,771,774,77
# ...

# %% [raw]
# #Challenge 3: Multiples of 3 and 5 solutions
#
# sum_num1 = 0                       #initialize result data 1
# sum_num2 = 0                       #initialize result data 2
# num1 = 3                           #define number 1
# num2 = 5                           #define number 2
#
# for i in range(1,1000):                             #create loop from 1 to 999
#     mul_of_num1 = num1 * i                          #get the multiple of number 1 with 1 to 999
#     #print(mul_of_num1, end=',')
#     if mul_of_num1 < 1000:                          #if the result of multiple of number 1 with i less than 1000
#         sum_num1= mul_of_num1 + sum_num1            ## add it with sum_num1
#     else:                                           ### if result of multiple of number 1 with i more than 999
#         break                                       ### jump out from the loop immediately
#
# for i in range(1,1000):                             #create loop from 1 to 999
#     mul_of_num2 = num2 * i                          #get the multiple of number 2 with 1 to 999
#     #print(mul_of_num2, end=': ')
#     if mul_of_num2 < 1000:                          #if the result of multiple of number 2 with i less than 1000
#         sum_num2= mul_of_num2 + sum_num2            ## add it with sum_num2
#     else:                                           ### if result of multiple of number 2 with i more than 999
#         break                                       ### jump out from the loop immediately
#
# #print out the result, sum_num1 + sum_num2
# print(sum_num1 + sum_num2, end = '= Sum of all the multiples of 3 and 5 below 1,000')

# %% [markdown]
# ### Challenge 4: String Compressor
# Implement a method to perform basic string compression using the counts of repeated characters. (This is called run-length encoding.) For example, the string "aabcccccaaa" would become a2b1c5a3. If the “compressed” string would not become smaller than the original string, your method should return the original string. You can assume the string has only uppercase and lowercase letters (a–z). Specify whether your solution is case sensitive or case insensitive and what you would need to change to make it the other. Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
def strCompressor(strInput, case_sensitive=True):
    len_strInput = len(strInput)
    strOutput = []
    i = 0
    #print(len_strInput, end='len,')
    if case_sensitive==False:
        strInput = strInput.lower()
    
    
    while i < len_strInput:
        iCharCounter = 1
        strOutput.append(strInput[i])
        #print(i, end='i')
        for j in range(i,len_strInput):
            #print(j, end='j,')
            
            if (j+1) >= len_strInput:
                i=j
                break
                
            if strInput[j] == strInput[j+1]:
                iCharCounter = iCharCounter + 1    
            else:
                i = j
                break

        strOutput.append(str(iCharCounter))
            
        i = i+1

    
    
    ans_out= ''.join(strOutput)
    print(ans_out)
    #if len(ans_out) > len_strInput:
    #    print(strInput)
    #else:
    #    print(ans_out)

# %%
strCompressor('wwaaaqqeqqAAAaaaa', True)
strCompressor('wwaaaqqeqqAAAaaaa', False)
# Out:
# w2a3q2e1q2A3a4
# w2a3q2e1q2a7

# %% [raw]
# #Challenge 4: String Compressor solution
#
# def strCompressor(strInput, case_sensitive=True):          #define a method strCompressor with 2 parameters,
#                                                            ## 1. strInput: the input string for compression
#                                                            ## 2. case_sensitive: True=sensitive, False=insensitive
#     len_strInput = len(strInput)                           # store the len of input string into len_strInput
#     strOutput = []                                         # create a empty list strOutput
#     i = 0                                                  # initialize i for while loop
#     #print(len_strInput, end='len,')
#     if case_sensitive==False:                              #convert the input string to lower case if case_senstive=False
#         strInput = strInput.lower()
#
#
#     while i < len_strInput:                                #create a while loop when i less than len_strInput
#         iCharCounter = 1                                   #initialize character counter
#         strOutput.append(strInput[i])                      #store the examine character in strOutput
#         #print(i, end='i')
#         for j in range(i,len_strInput):                    #create a for loop from the position of the examine charactor
#                                                            ## to the len of strInput
#             #print(j, end='j,')
#
#             if (j+1) >= len_strInput:                      #exit for-loop if j+1 greater than len_strInput to prevent index                                                            ##error
#                 i=j                                        #store the position of next examine character then exit for-loop
#                 break
#
#             if strInput[j] == strInput[j+1]:               #increase character counter iCharCounter by 1 if the examine                     iCharCounter = iCharCounter + 1            ## character same with next position of the examine character
#             else:
#                 i = j                                      #if the examine character not same with next  position of the
#                 break                                      ## examine character, store the position of next examine                                                                    ### character then exit for-loop
#
#         strOutput.append(str(iCharCounter))                #store the total number of same character in strOutput
#
#         i = i+1                                            #jump to the next examine character
#
#
#
#     ans_out= ''.join(strOutput)                            #convert the data in the strOutput list to string
#     #print(ans_out)
#     if len(strOutput) > len_strInput:                      #If the compressed string strOutper smaller than the
#         print(strInput)                                    ##original string strInput, return the original string.
#     else:
#         print(ans_out)

# %% [markdown]
# ### *BONUS* Challenge: FizzBuzz
# Write a program that prints all of the numbers from 1 to 100. For multiples of 3, instead of the number, print "Fizz;" for multiples of 5, print "Buzz." For numbers that are multiples of both 3 and 5, print "FizzBuzz." Afterward, write a brief explanation walking through your code's logic in markdown.

# %%
num1 = 3
num2 = 5
num3 = 3*5

grp_num1 =[]
grp_num2 =[]
grp_num3 =[]
grp_answer =[]

str_num1="Fizz;"
str_num2="Buzz."
str_num3="FizzBuzz." 

for i in range(1,100):
    mul_of_num1 = num1 * i

    if mul_of_num1 > 100:
        break
    else:
        #print(mul_of_num1, end=',')
        grp_num1.append(mul_of_num1)
        
#print()

for i in range(1,100):
    mul_of_num2 = num2 * i

    if mul_of_num2 > 100:
        break
    else:
        #print(mul_of_num2, end=',')
        grp_num2.append(mul_of_num2)
        
#print()

for i in range(1,100):
    mul_of_num3 = num3 * i

    if mul_of_num3 > 100:
        break
    else:
        #print(mul_of_num3, end=',')
        grp_num3.append(mul_of_num3)
        
#print()


for i in range(1,101):
    grp_answer.append(i)
#grp_answer = list(range(101)) 
#print(grp_answer)
    
#print()

for i in range(1,100):
    for j in range(len(grp_num3)):
        if grp_answer[i] == grp_num3[j]:
            grp_answer[i] = str_num3
    
    for j in range(len(grp_num2)):     
        if grp_answer[i] == grp_num2[j]:
            grp_answer[i] = str_num2
            
            
    for j in range(len(grp_num1)):     
        if grp_answer[i] == grp_num1[j]:
            grp_answer[i] = str_num1
    
print(grp_answer)
# Out:
# [1, 2, 'Fizz;', 4, 'Buzz.', 'Fizz;', 7, 8, 'Fizz;', 'Buzz.', 11, 'Fizz;', 13, 14, 'FizzBuzz.', 16, 17, 'Fizz;', 19, 'Buzz.', 'Fizz;', 22, 23, 'Fizz;', 'Buzz.', 26, 'Fizz;', 28, 29, 'FizzBuzz.', 31, 32, 'Fizz;', 34, 'Buzz.', 'Fizz;', 37, 38, 'Fizz;', 'Buzz.', 41, 'Fizz;', 43, 44, 'FizzBuzz.', 46, 47, 'Fizz;', 49, 'Buzz.', 'Fizz;', 52, 53, 'Fizz;', 'Buzz.', 56, 'Fizz;', 58, 59, 'FizzBuzz.', 61, 62, 'Fizz;', 64, 'Buzz.', 'Fizz;', 67, 68, 'Fizz;', 'Buzz.', 71, 'Fizz;', 73, 74, 'FizzBuzz.', 76, 77, 'Fizz;', 79, 'Buzz.', 'Fizz;', 82, 83, 'Fizz;', 'Buzz.', 86, 'Fizz;', 88, 89, 'FizzBuzz.', 91, 92, 'Fizz;', 94, 'Buzz.', 'Fizz;', 97, 98, 'Fizz;', 'Buzz.']

# %% [raw]
# #*BONUS* Challenge: FizzBuzz solution
#
# num1 = 3                                   #define number 1
# num2 = 5                                   #define number 2
# num3 = 3*5                                 #define number 3
#
# grp_num1 =[]                               #create empty list for group number 1
# grp_num2 =[]                               #create empty list for group number 2
# grp_num3 =[]                               #create empty list for group number 3
# grp_answer =[]                             #create empty list for group answer
#
# str_num1="Fizz;"                           #define string of number 1
# str_num2="Buzz."                           #define string of number 2
# str_num3="FizzBuzz."                       #define string of number 3
#
# for i in range(1,100):                     #create a for-loop from 1 to 99
#     mul_of_num1 = num1 * i                 #store multiple of number 1 with i into mul_of_num1
#
#     if mul_of_num1 > 100:                  #if mul_of_num1 greater than 100 exit for-loop
#         break
#     else:
#         #print(mul_of_num1, end=',')
#         grp_num1.append(mul_of_num1)       ##else store mul_of_num1 into group number 1, grp_num1
#
# #print()
#
# for i in range(1,100):                     #create a for-loop from 1 to 99
#     mul_of_num2 = num2 * i                 #store multiple of number 2 with i into mul_of_num2
#
#     if mul_of_num2 > 100:                  #if mul_of_num2 greater than 100 exit for-loop
#         break
#     else:
#         #print(mul_of_num2, end=',')
#         grp_num2.append(mul_of_num2)       #else store mul_of_num2 into group number 2, grp_num2
#
# #print()
#
# for i in range(1,100):                     #create a for-loop from 1 to 99
#     mul_of_num3 = num3 * i                 #store multiple of number 3 with i into mul_of_num3
#
#     if mul_of_num3 > 100:                  #if mul_of_num3 greater than 100 exit for-loop
#         break
#     else:
#         #print(mul_of_num3, end=',')
#         grp_num3.append(mul_of_num3)       #else store mul_of_num3 into group number 3, grp_num3
#
# #print()
#
#
# for i in range(1,101):                     #create a for-loop from 1 to 100
#     grp_answer.append(i)
#
# #print(grp_answer)
#
# #print()
#
# for i in range(1,100):                         #create a for-loop from 1 to 99
#     for j in range(len(grp_num3)):             #create a for-loop from 0 to len of grp_num3
#         if grp_answer[i] == grp_num3[j]:       #if grp_answer=grp_num3 then replace grp_answer by string of number 3
#             grp_answer[i] = str_num3
#
#     for j in range(len(grp_num2)):             #create a for-loop from 1 to 99
#         if grp_answer[i] == grp_num2[j]:       #create a for-loop from 0 to len of grp_num2
#             grp_answer[i] = str_num2           #if grp_answer=grp_num2 then replace grp_answer by string of number 2
#
#
#     for j in range(len(grp_num1)):             #create a for-loop from 1 to 99
#         if grp_answer[i] == grp_num1[j]:       #create a for-loop from 0 to len of grp_num1
#             grp_answer[i] = str_num1           #if grp_answer=grp_num1 then replace grp_answer by string of number 1
#
# print(grp_answer)                              #print out result
